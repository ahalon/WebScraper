# %% [markdown]
# # Packages import

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Ceneo Scraper

# %% [markdown]
# 1. Provide url of the prodcut ' s opinions page.

# %%
product_code = "84869312"
url = f'https://www.ceneo.pl/{product_code}#tab-reviews'

# %% [markdown]
# 2. Send request to provided URL

# %%
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# 3. Fetch product name

# %%
page_dom = BeautifulSoup(response.text, "html.parser")
print(type(page_dom))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 page_dom = BeautifulSoup(response.text, "html.parser")
#       2 print(type(page_dom))
#
# NameError: name 'BeautifulSoup' is not defined

# %%
product_name = page_dom.select_one('h1').get_text()
print(product_name)
print(type(product_name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 product_name = page_dom.select_one('h1').get_text()
#       2 print(product_name)
#       3 print(type(product_name))
#
# NameError: name 'page_dom' is not defined
