# %% [markdown]
# ## Packages import

# %%
import yaml
import requests
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup

# %% [markdown]
# ## Apollo Scraper

# %%
with open("conifg.yaml","r", encoding = "UTF-8") as yf:
    config = yaml.safe_load(yf)
username = config["credentials"]['user']
password = config["credentials"]['password']
credentials = HTTPBasicAuth(username, password)

# %%
url = "https://planzajec.uek.krakow.pl/index.php?typ=G&id=252681&okres=1"
response = requests.get(url, auth=credentials)
print(response.status_code)

# %%
page_dom = BeautifulSoup(response.text, "html.parser")

# %%
group = page_dom.select_one("dive.grupa").get_text(strip=True)
print(group)

# %%
classes_tag = page_dom.select_one("table")
with open("temp.html", "w", encoding="UTF-8") as hf:
    hf.write(classes_tag.prettify())
classes = pd.read_html("temp.html", encoding="UTF-8")[0]
os.remove("temp.html")

# %%
if not os.path.exists("schedules"):
    os.mkdir("schedules")

# %%
classes.to_csv(f"schedules/{group}.csv")
